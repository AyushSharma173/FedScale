# %%
import torch
import logging
import math
from torch.autograd import Variable
import numpy as np

import os

import sys
sys.argv = ['']  #
import fedscale.cloud.config_parser as parser
from fedscale.cloud.execution.torch_client import TorchClient
from fedscale.cloud.execution.executor import Executor
from argparse import Namespace
import fedscale.cloud.commons as commons

# %%
### On CPU

parser.args = Namespace(
    use_cuda="False",
    cuda_device=0,
    num_executors=1,
    this_rank=0,
    ps_ip="127.0.0.1",
    ps_port=50051,
    wandb_token="",
    job_name="demo_job",
    time_stamp="123456",
    task="cv",          # Let's assume computer vision (CV) task
    engine=commons.PYTORCH,   # **VERY IMPORTANT** or else get_client_trainer() crashes
    model="resnet20_cifar10",   # Simple model
    model_zoo="fedscale-torch-zoo",
    data_set="cifar10", # Simple dataset
    data_dir="./data",  # Data folder
    num_class=10,       # CIFAR-10 => 10 classes
    num_participants=1,  # 1 client (minimal setup)
    data_map_file=None,  # Can be None if not using mapping
    memory_capacity=0,   # Dummy value
    test_bsz=32,         # Testing batch size,
    log_path="./logs",
    test_ratio=0.1,
    test_interval=1,
    test_epochs=1,
    test_batch_size=32,
    test_num_workers=4,
    test_pin_memory=True,
    batch_size=128,
    local_steps=1,
    learning_rate=0.01,
    momentum=0.9,
    weight_decay=0.0001,
    device_conf_file=None,
    experiment_mode=commons.SIMULATION_MODE,
    num_loaders=4,
    pin_memory=True,
    num_workers=4,
    num_clients=1,
    num_rounds=1,
    num_epochs=1,
    gradient_policy="fedavg",
    overcommitment=1.3,
    decay_round=5,
    decay_factor=0.5,
    min_learning_rate=1e-5,
    save_checkpoint=False,
    filter_less=0,
)
Demo_Executor = Executor(parser.args)
Demo_Executor.run()
# Out:
# (04-28) 22:39:19 INFO     [fllibs.py:97] Initializing the model ...
# (04-28) 22:39:19 INFO     [executor.py:77] (EXECUTOR:0) is setting up environ ...
# (04-28) 22:39:21 INFO     [executor.py:123] Data partitioner starts ...
# (04-28) 22:39:21 INFO     [divide_data.py:105] Randomly partitioning data, 50000 samples...
# (04-28) 22:39:21 INFO     [divide_data.py:105] Randomly partitioning data, 10000 samples...
# (04-28) 22:39:21 INFO     [executor.py:141] Data partitioner completes ...
# (04-28) 22:39:21 INFO     [channel_context.py:20] %%%%%%%%%% Opening grpc connection to 127.0.0.1 %%%%%%%%%%
# (04-28) 22:39:21 INFO     [executor.py:404] Start monitoring events ...
# (04-28) 22:39:23 INFO     [model_test_module.py:307] Rank 0: Test set: Average loss: 7.5488, Top-1 Accuracy: 89.0/1000 (0.089), Top-5 Accuracy: 0.493
# (04-28) 22:39:23 INFO     [torch_client.py:264] Test results: Eval_time 0.5758, test_loss 7.5488, test_accuracy 8.90%, test_5_accuracy 49.30%
#
# ...
